# %%
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('rate', 50)
engine.say("Yes master I will do that.")
engine.runAndWait()

# %%
engine = pyttsx3.init()
rate = engine.getProperty('rate')
engine.setProperty('rate', rate)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[8].id)
engine.say('The quick brown fox jumped over the lazy dog.')
engine.runAndWait()

# %%
rate = engine.getProperty('rate')

# %%
rate
# Out:
# 200

# %%
# Test Edge face detection

# %%
import cv2

# %%
detector = cv2.FaceDetectorYN_create('face_detection_yunet_2023mar.onnx',
                          "", 
                          (300, 300),
                          score_threshold=0.5)

# %%
# Read image
img = cv2.imread("resources/generated/2024-12-1015:21:11.600029.png")
# Get image shape
img_W = int(img.shape[1])
img_H = int(img.shape[0])
# Set input size
detector.setInputSize((img_W, img_H))
# Getting detections
detections = detector.detect(img)

# %%
import matplotlib.pyplot as plt

# %%
# some other interesting resouces are also returned:
f1 =detections[1][0].astype(int)[:4]
f2 =detections[1][1].astype(int)[:4]

# %%
f2
# Out:
# array([844, 162, 173, 224])

# %%
plt.imshow(img[f1[1]: f1[1] + f1[3], f1[0]: f1[0] + f1[2]])
